# %% [markdown]
# # 필요한 모듈 활용하기

# %% [markdown]
# # 필요한 모듈 사용하기

# %%
import numpy as np
import pandas as pd

from tensorflow import keras
#from tensorflow.keras.datasets import mnist
from tensorflow.keras.datasets import fashion_mnist

from tensorflow.keras.models import Sequential  #모델 쌓기위해 필요한
from tensorflow.keras.layers import Activation, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical  #정수인 y값 원핫인코딩하기 위해서

from keras.callbacks import ModelCheckpoint   # 최적의 모델을 선택

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# ### 압축파일을 풀 경로

# %%
# %cd /content/drive/MyDrive/camp/image

# !unzip -qq "/content/drive/MyDrive/camp/data.zip"
# Out:
# /content/drive/MyDrive/camp/image

# %% [markdown]
# ### 푼 데이터 수 확인하기

# %%
# 데이터 읽기

import torchvision

data = torchvision.datasets.ImageFolder(
    root = '/content/drive/MyDrive/camp/image',
    transform=None
)

# 출처: https://signing.tistory.com/80 [끄적거림:티스토리]

# %%
# 푼 데이터 수 확인하기

from glob import glob
filepaths = list(glob('/content/drive/MyDrive/camp/image/*.jpg'))

len(filepaths)
# Out:
# 0

# %%
import torchvision

data = torchvision.datasets.ImageFolder(
    root = '',
    transform=None
)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-1-c0c07c6ca485> in <module>
#       3 data = torchvision.datasets.ImageFolder(
#       4     root = '/content/drive/MyDrive/캠프 참가/대학부 데이터셋.zip',
# ----> 5     transform=None
#       6 )
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     314             transform=transform,
#     315             target_transform=target_transform,
# --> 316             is_valid_file=is_valid_file,
#     317         )
#     318         self.imgs = self.samples
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     143     ) -> None:
# ...
